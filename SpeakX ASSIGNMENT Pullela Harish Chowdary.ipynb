# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SpeakA=pd.read_csv("C:/Users/Harish/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
SpeakA.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
SpeakA.shape
# Out:
# (7043, 21)

# %%
SpeakA.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
SpeakA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
SpeakA.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
SpeakA.isna().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
SpeakA.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
SpeakA['TotalCharges'] = SpeakA['TotalCharges'].replace(' ', np.nan, regex=True)

# %%
SpeakA['TotalCharges'] = pd.to_numeric(SpeakA['TotalCharges'])

mean_TotalCharges = SpeakA['TotalCharges'].mean()

SpeakA['TotalCharges'].fillna(value=mean_TotalCharges, inplace=True)

# %%
SpeakA.head(490)
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    7590-VHVEG  Female              0     Yes         No       1
# 1    5575-GNVDE    Male              0      No         No      34
# 2    3668-QPYBK    Male              0      No         No       2
# 3    7795-CFOCW    Male              0      No         No      45
# 4    9237-HQITU  Female              0      No         No       2
# ..          ...     ...            ...     ...        ...     ...
# 485  7971-HLVXI    Male              0     Yes        Yes      72
# 486  9094-AZPHK  Female              0      No         No      15
# 487  3649-JPUGY    Male              0      No         No      72
# 488  4472-LVYGI  Female              0     Yes        Yes       0
# 489  8372-JUXUI    Male              0      No        Yes       1
#
#     PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             No  No phone service             DSL             No  ...
# ...

# %%
SpeakA.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
SpeakA['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
SpeakA['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
SpeakA['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
SpeakA['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
SpeakA['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
SpeakA['OnlineSecurity'].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
SpeakA['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
SpeakA['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
SpeakA['OnlineBackup'].value_counts()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
SpeakA['DeviceProtection'].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
SpeakA['TechSupport'].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
SpeakA['StreamingTV'].value_counts()
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %%
SpeakA['StreamingMovies'].value_counts()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
SpeakA['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
SpeakA['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
SpeakA['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
SpeakA['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
SpeakA['OnlineSecurity'] = SpeakA['OnlineSecurity'].replace('No internet service', 'No', regex=True)

# %%
SpeakA['MultipleLines'] = SpeakA['MultipleLines'].replace('No phone service', 'No', regex=True)

# %%
SpeakA['OnlineBackup'] = SpeakA['OnlineBackup'].replace('No internet service', 'No', regex=True)

# %%
SpeakA['DeviceProtection'] = SpeakA['DeviceProtection'].replace('No internet service', 'No', regex=True)

# %%
SpeakA['TechSupport'] = SpeakA['TechSupport'].replace('No internet service', 'No', regex=True)

# %%
SpeakA['StreamingTV'] = SpeakA['StreamingTV'].replace('No internet service', 'No', regex=True)

# %%
SpeakA['StreamingMovies'] = SpeakA['StreamingMovies'].replace('No internet service', 'No', regex=True)

# %%
SpeakA
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0              No            No             DSL             No  ...
# ...

# %%
sns.boxplot(x=SpeakA["tenure"],y=SpeakA["Churn"])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Churn'>

# %%
sns.boxplot(x=SpeakA["MonthlyCharges"],y=SpeakA["Churn"])
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Churn'>

# %%
sns.boxplot(x=SpeakA["TotalCharges"],y=SpeakA["Churn"])
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Churn'>

# %% [markdown]
# # Conclusion: I have observed that Yes of Churn means Churn users have outliers in tenure and TotalCharges

# %%
# Total Charges vs Tenure
plt.figure(figsize=(10, 6))
sns.scatterplot(data=SpeakA, x='tenure', y='TotalCharges', hue='Churn')
plt.title('Total Charges vs Tenure by Churn')
plt.xlabel('tenure')
plt.ylabel('Total Charges')
plt.show()

# %% [markdown]
# # Conclusion: There is a positive linear relation between tenure and TotalCharges

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(x='MonthlyCharges', y='tenure', data=SpeakA, hue='Churn')
plt.title('Monthly Charges vs Tenure')
plt.show()

# %% [markdown]
# # Conclusion: (No) of Churn has more tenure and monthly charges

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x="gender", data=SpeakA, hue="Churn")
plt.title('Gender vs Churn')
plt.show()

# %% [markdown]
# # Conclusion: Almost similar distribution between female and male count and Based on Churn as No category has more value distribution between females and males. No Churn users have more distribution

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x="Contract", data=SpeakA, hue="Churn")
plt.title('Contract vs Churn')
plt.show()

# %% [markdown]
# # Conclusion: Month-to-month contract users are more than one year contract and two-year. Based on Churn too month-to-month users have more users

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x="PaymentMethod", data=SpeakA, hue="Churn")
plt.title('PaymentMethod vs Churn')
plt.show()

# %% [markdown]
# # Conclusion: Most users have opted electronic check payment option. (No) category churn users have equally opted for all payment method options

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x="InternetService", data=SpeakA, hue="Churn")
plt.title('InternetService vs Churn')
plt.show()

# %% [markdown]
# # Conclusion: No category of Churn users has DSL internet service. When combined with the yes and no categories of churn users then DSL and Fiber optic internet services have equal distributions.

# %%
plt.figure(figsize=(15, 6))
sns.distplot(SpeakA['tenure'])
plt.title('Tenure distribution')
plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Conclusion: 0-20 density has more value of tenure like 0-20 has more tenure distribution

# %%
SpeakA.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.016567        0.220173      0.102395
# tenure               0.016567  1.000000        0.247900      0.824757
# MonthlyCharges       0.220173  0.247900        1.000000      0.650468
# TotalCharges         0.102395  0.824757        0.650468      1.000000

# %%
sns.heatmap(SpeakA.corr(), vmin=-1, vmax=1, annot=True,cmap="rocket_r")
# Out:
# <AxesSubplot:>

# %%
from sklearn import preprocessing 
 
label_encoder = preprocessing.LabelEncoder() 

SpeakA['gender']= label_encoder.fit_transform(SpeakA['gender'])

# %%
SpeakA['Partner']= label_encoder.fit_transform(SpeakA['Partner'])

# %%
SpeakA['Dependents']= label_encoder.fit_transform(SpeakA['Dependents'])

# %%
SpeakA['PhoneService']= label_encoder.fit_transform(SpeakA['PhoneService'])

# %%
SpeakA['MultipleLines']= label_encoder.fit_transform(SpeakA['MultipleLines'])

# %%
SpeakA['InternetService']= label_encoder.fit_transform(SpeakA['InternetService'])

# %%
SpeakA['OnlineSecurity']= label_encoder.fit_transform(SpeakA['OnlineSecurity'])

# %%
SpeakA['OnlineBackup']= label_encoder.fit_transform(SpeakA['OnlineBackup'])

# %%
SpeakA['DeviceProtection']= label_encoder.fit_transform(SpeakA['DeviceProtection'])

# %%
SpeakA['TechSupport']= label_encoder.fit_transform(SpeakA['TechSupport'])

# %%
SpeakA['StreamingTV']= label_encoder.fit_transform(SpeakA['StreamingTV'])

# %%
SpeakA['StreamingMovies']= label_encoder.fit_transform(SpeakA['StreamingMovies'])

# %%
SpeakA['Contract']= label_encoder.fit_transform(SpeakA['Contract'])

# %%
SpeakA['PaperlessBilling']= label_encoder.fit_transform(SpeakA['PaperlessBilling'])

# %%
SpeakA['PaymentMethod']= label_encoder.fit_transform(SpeakA['PaymentMethod'])

# %%
SpeakA['Churn']= label_encoder.fit_transform(SpeakA['Churn'])

# %%
SpeakA
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
SpeakA.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.008414       0.142948  0.142057   -0.024526  0.331941
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.017021      -0.038653  0.143106    0.080972  0.327203
# OnlineBackup     -0.013773       0.066572  0.141498    0.023671  0.360277
# DeviceProtection -0.002105       0.059428  0.153786    0.013963  0.360653
# TechSupport      -0.009212      -0.060625  0.119999    0.063268  0.324221
# ...

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(SpeakA.corr(), vmin=-1, vmax=1, annot=True,cmap="rocket_r")
# Out:
# <AxesSubplot:>

# %%
SpeakA.drop('customerID', inplace=True, axis=1)

# %%
SpeakA
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %% [markdown]
# # Building the Churn Prediction Model

# %% [markdown]
# # Random Forest Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score
from scipy.stats import randint

# %%
y = SpeakA.Churn # dependent variable
y.shape
x = SpeakA.drop('Churn', axis=1) # independent variable

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3)

# %%
rf = RandomForestClassifier()
rf.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(test_x)

# %%
# Random Forest evaluation
rf_accuracy = accuracy_score(test_y, y_pred)
rf_precision = precision_score(test_y, y_pred)
rf_recall = recall_score(test_y, y_pred)
rf_f1 = f1_score(test_y, y_pred)

print("Accuracy:", rf_accuracy)
print("Precision:", rf_precision)
print("recall:", rf_recall)
print("f1_score:", rf_f1)
# Out:
# Accuracy: 0.7946048272598202
# Precision: 0.648960739030023
# recall: 0.4991119005328597
# f1_score: 0.5642570281124498

# %%
cm = confusion_matrix(test_y, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# # Identifying best hyperparameters and estimators and fitting into random forest and building

# %%
from sklearn.model_selection import RandomizedSearchCV
param_dist = {'n_estimators': randint(50,500), 'max_depth': randint(1,20)}

rf = RandomForestClassifier()

rand_search = RandomizedSearchCV(rf,
                                 param_distributions = param_dist,
                                 n_iter=5,
                                 cv=5)

rand_search.fit(train_x, train_y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001DD0D2C04C0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001DD0D2C02E0>})

# %%
best_rf = rand_search.best_estimator_

print('Best hyperparameters:',  rand_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 11, 'n_estimators': 315}

# %%
y_pred1 = best_rf.predict(test_x)

cm = confusion_matrix(test_y, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
# Random Forest evaluation
rf1_accuracy = accuracy_score(test_y, y_pred1)
rf1_precision = precision_score(test_y, y_pred1)
rf1_recall = recall_score(test_y, y_pred1)
rf1_f1 = f1_score(test_y, y_pred1)

print("Accuracy:", rf1_accuracy)
print("Precision:", rf1_precision)
print("recall:", rf1_recall)
print("f1_score:", rf1_f1)
# Out:
# Accuracy: 0.8140085186938003
# Precision: 0.694954128440367
# recall: 0.5381882770870338
# f1_score: 0.6066066066066066

# %% [markdown]
# # Logistic Regression Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score
from sklearn.linear_model import LogisticRegression

# %%
y = SpeakA.Churn
y.shape
x = SpeakA.drop('Churn', axis=1)

# %%
from sklearn.model_selection import  train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16)

# fit the model with data
logreg.fit(train_x, train_y)

y_pred = logreg.predict(test_x)
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
cm = confusion_matrix(test_y, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
LG_accuracy = accuracy_score(test_y, y_pred)
LG_precision = precision_score(test_y, y_pred)
LG_recall = recall_score(test_y, y_pred)
LG_f1 = f1_score(test_y, y_pred)

print("Accuracy:", LG_accuracy)
print("Precision:", LG_precision)
print("recall:", LG_recall)
print("f1_score:", LG_f1)
# Out:
# Accuracy: 0.8017037387600567
# Precision: 0.673773987206823
# recall: 0.5429553264604811
# f1_score: 0.6013320647002854

# %% [markdown]
# # Gradient Boosting Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score
from sklearn.ensemble import GradientBoostingClassifier

# %%
y = SpeakA.Churn
y.shape
x = SpeakA.drop('Churn', axis=1)

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3)

# %%
GB = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0).fit(train_x, train_y)
y_pred = GB.predict(test_x)

# %%
cm = confusion_matrix(test_y, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
GB_accuracy = accuracy_score(test_y, y_pred)
GB_precision = precision_score(test_y, y_pred)
GB_recall = recall_score(test_y, y_pred)
GB_f1 = f1_score(test_y, y_pred)

print("Accuracy:", GB_accuracy)
print("Precision:", GB_precision)
print("recall:", GB_recall)
print("f1_score:", GB_f1)
# Out:
# Accuracy: 0.8069096071935636
# Precision: 0.6399132321041214
# recall: 0.5493482309124768
# f1_score: 0.591182364729459
